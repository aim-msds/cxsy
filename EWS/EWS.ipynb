# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-Early-Warning-Signals-on-Real-Dataset" data-toc-modified-id="Using-Early-Warning-Signals-on-Real-Dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Using Early Warning Signals on Real Dataset</a></span><ul class="toc-item"><li><span><a href="#Standard-Deviation" data-toc-modified-id="Standard-Deviation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Standard Deviation</a></span><ul class="toc-item"><li><span><a href="#Dam" data-toc-modified-id="Dam-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Dam</a></span></li><li><span><a href="#Rain" data-toc-modified-id="Rain-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Rain</a></span></li><li><span><a href="#NIA" data-toc-modified-id="NIA-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>NIA</a></span></li><li><span><a href="#ONI" data-toc-modified-id="ONI-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>ONI</a></span></li><li><span><a href="#MWSS" data-toc-modified-id="MWSS-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>MWSS</a></span></li></ul></li><li><span><a href="#Autocorrelation-with-Lag-1" data-toc-modified-id="Autocorrelation-with-Lag-1-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Autocorrelation with Lag 1</a></span><ul class="toc-item"><li><span><a href="#Dam" data-toc-modified-id="Dam-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Dam</a></span></li><li><span><a href="#Rain" data-toc-modified-id="Rain-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Rain</a></span></li><li><span><a href="#NIA" data-toc-modified-id="NIA-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>NIA</a></span></li><li><span><a href="#ONI" data-toc-modified-id="ONI-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>ONI</a></span></li><li><span><a href="#MWSS" data-toc-modified-id="MWSS-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>MWSS</a></span></li></ul></li><li><span><a href="#Skewness" data-toc-modified-id="Skewness-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Skewness</a></span><ul class="toc-item"><li><span><a href="#Dam" data-toc-modified-id="Dam-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Dam</a></span></li><li><span><a href="#Rain" data-toc-modified-id="Rain-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Rain</a></span></li><li><span><a href="#NIA" data-toc-modified-id="NIA-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>NIA</a></span></li><li><span><a href="#ONI" data-toc-modified-id="ONI-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>ONI</a></span></li><li><span><a href="#MWSS" data-toc-modified-id="MWSS-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>MWSS</a></span></li></ul></li><li><span><a href="#Conditional-Heteroskedasticity" data-toc-modified-id="Conditional-Heteroskedasticity-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Conditional Heteroskedasticity</a></span><ul class="toc-item"><li><span><a href="#Dam" data-toc-modified-id="Dam-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Dam</a></span></li><li><span><a href="#Rain" data-toc-modified-id="Rain-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Rain</a></span></li><li><span><a href="#NIA" data-toc-modified-id="NIA-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>NIA</a></span></li><li><span><a href="#ONI" data-toc-modified-id="ONI-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>ONI</a></span></li><li><span><a href="#MWSS" data-toc-modified-id="MWSS-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>MWSS</a></span></li></ul></li><li><span><a href="#Autoregression-AR(1)" data-toc-modified-id="Autoregression-AR(1)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Autoregression AR(1)</a></span><ul class="toc-item"><li><span><a href="#Dam" data-toc-modified-id="Dam-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Dam</a></span></li><li><span><a href="#Rain" data-toc-modified-id="Rain-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Rain</a></span></li><li><span><a href="#NIA" data-toc-modified-id="NIA-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>NIA</a></span></li><li><span><a href="#ONI" data-toc-modified-id="ONI-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>ONI</a></span></li><li><span><a href="#MWSS" data-toc-modified-id="MWSS-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>MWSS</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Using Early Warning Signals on Real Dataset
#
# * ONI (Oceanic Niño Index)
# * Rain
# * NIA (National Irrigation Administration)
# * MWSS (Metropolitan Waterworks and Sewerage System)
# * Dam

# %%
import sys
import pandas as pd

import matplotlib.pylab as plt

from ews import *

# %%
full_data = pd.read_csv('Angat_dataset_raw.csv')
full_data.head()
# Out:
#          Date  Rain  ONI        NIA   MWSS     Dam
# 0  01/01/2001   0.0 -0.7  38.225693  44.73  214.60
# 1  01/02/2001   0.0 -0.7  57.996530  45.98  214.55
# 2  01/03/2001   0.0 -0.7  49.119213  45.98  214.38
# 3  01/04/2001   0.0 -0.7  47.034720  44.69  214.18
# 4  01/05/2001   0.0 -0.7  42.223380  47.17  213.96

# %%
data = full_data.copy()
data_clean = data.dropna().reset_index(drop=True)
data_clean.head()
# Out:
#          Date  Rain  ONI        NIA   MWSS     Dam
# 0  01/01/2001   0.0 -0.7  38.225693  44.73  214.60
# 1  01/02/2001   0.0 -0.7  57.996530  45.98  214.55
# 2  01/03/2001   0.0 -0.7  49.119213  45.98  214.38
# 3  01/04/2001   0.0 -0.7  47.034720  44.69  214.18
# 4  01/05/2001   0.0 -0.7  42.223380  47.17  213.96

# %%
for column in data_clean.columns:
    if column != 'Date':
        data_clean[[column, 'Date']].plot(x='Date', rot=20, legend=False, title=column)

# %% [markdown]
# ## Standard Deviation
# ### Dam

# %%
dic = {'data': data_clean.Dam, 
      'title': 'Dam',
      'method_name': 'Std'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 2.673903098937558e-09
# Tau : -0.06530949742697892
# Slope : -3.855718984351416e-05

# %% [markdown]
# ### Rain

# %%
dic = {'data': data_clean.Rain, 
      'title': 'Rain',
      'method_name': 'Std'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.5902211997222352
# Slope : 0.0014922977402981774

# %% [markdown]
# ### NIA

# %%
dic = {'data': data_clean.NIA, 
      'title': 'NIA',
      'method_name': 'Std'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.34435048710057004
# Slope : 0.0006140329060392457

# %% [markdown]
# ### ONI

# %%
dic = {'data': data_clean.ONI, 
      'title': 'ONI',
      'method_name': 'Std'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.17113369881644844
# Slope : 3.6574785386331754e-05

# %% [markdown]
# ### MWSS

# %%
dic = {'data': data_clean.MWSS, 
      'title': 'MWSS',
      'method_name': 'Std'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.1378440192698611
# Slope : 0.00011500037349872251

# %% [markdown]
# ## Autocorrelation with Lag 1
# ### Dam

# %%
dic = {'data': data_clean.Dam, 
      'title': 'Dam',
      'method_name': 'Autocorrelation'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.18859492014261411
# Slope : 4.637108255322322e-08

# %% [markdown]
# ### Rain

# %%
dic = {'data': data_clean.Rain, 
      'title': 'Rain',
      'method_name': 'Autocorrelation'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.7714463162570163
# Slope : 6.947264097033731e-05

# %% [markdown]
# ### NIA

# %%
dic = {'data': data_clean.NIA, 
      'title': 'NIA',
      'method_name': 'Autocorrelation'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.4179251601592307
# Slope : -8.223505365709608e-06

# %% [markdown]
# ### ONI

# %%
dic = {'data': data_clean.ONI, 
      'title': 'ONI',
      'method_name': 'Autocorrelation'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 1.7186252421197423e-13
# Tau : 0.08087905466081917
# Slope : 2.7314485877052584e-08

# %% [markdown]
# ### MWSS

# %%
dic = {'data': data_clean.MWSS, 
      'title': 'Rain',
      'method_name': 'Autocorrelation'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.206423736863892
# Slope : 1.1954614298459066e-05

# %% [markdown]
# ## Skewness
# ### Dam

# %%
dic = {'data': data_clean.Dam, 
      'title': 'Dam',
      'method_name': 'Skewness'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.20781784166642464
# Slope : -2.3927436213036588e-05

# %% [markdown]
# ### Rain

# %%
dic = {'data': data_clean.Rain, 
      'title': 'Rain',
      'method_name': 'Skewness'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.7417076140946577
# Slope : -0.003897480825755292

# %% [markdown]
# ### NIA

# %%
dic = {'data': data_clean.NIA, 
      'title': 'NIA',
      'method_name': 'Skewness'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.4170891960104898
# Slope : -7.682984928369513e-05

# %% [markdown]
# ### ONI

# %%
dic = {'data': data_clean.ONI, 
      'title': 'ONI',
      'method_name': 'Skewness'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.7591811570541791
# Slope : 0.0003354099152486975

# %% [markdown]
# ### MWSS

# %%
dic = {'data': data_clean.MWSS, 
      'title': 'MWSS',
      'method_name': 'Skewness'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0014985323849281418
# Tau : -0.03484704599108324
# Slope : -1.8033797321572205e-05

# %% [markdown]
# ## Conditional Heteroskedasticity
# ### Dam

# %%
# data_clean
data_clean_ = data_clean.copy()
data_clean_['Date'] = pd.to_datetime(data_clean_['Date'])
data_clean_['Time'] = (data_clean_['Date'] - min(data_clean_['Date'])).dt.days

# %%
dic = {'data': data_clean_.Dam, 
       'time' : data_clean_['Time'],
      'title': 'Dam',
      'method_name': 'CH'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.5243520947803507
# Slope : -5.329699812833786e-14

# %% [markdown]
# ### Rain

# %%
dic = {'data': data_clean_.Rain, 
       'time' : data_clean_['Time'],
      'title': 'Rain',
      'method_name': 'CH'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.5353387378364209
# Slope : 4.0275151836381335e-05

# %% [markdown]
# ### NIA

# %%
dic = {'data': data_clean_.NIA, 
       'time' : data_clean_['Time'],
      'title': 'NIA',
      'method_name': 'CH'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.4396612548292735
# Slope : -7.481147610116512e-08

# %% [markdown]
# ### ONI

# %%
dic = {'data': data_clean_.ONI, 
       'time' : data_clean_['Time'],
      'title': 'ONI',
      'method_name': 'CH'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.5395313202718153
# Slope : -2.9875023534285357e-19

# %% [markdown]
# ### MWSS

# %%
dic = {'data': data_clean_.MWSS, 
       'time' : data_clean_['Time'],
      'title': 'MWSS',
      'method_name': 'CH'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : decreasing
# h : True
# p : 0.0
# Tau : -0.22409237235154558
# Slope : -1.221932889282632e-07

# %% [markdown]
# ## Autoregression AR(1)

# %% [markdown]
# ### Dam

# %%
dic = {'data': data_clean.Dam, 
      'title': 'Dam',
      'method_name': 'Autoregression'}

plot(data_clean, dic)
# Out:
# Mann Kendall Test Results
# -------------------------
# Trend : increasing
# h : True
# p : 0.0
# Tau : 0.17434260418894462
# Slope : 4.280734314139454e-08

# %% [markdown]
# ### Rain

# %%
dic = {'data': data_clean.Rain, 
      'title': 'Rain',
      'method_name': 'Autoregression'}

plot(data_clean, dic)

# %% [markdown]
# ### NIA

# %%
dic = {'data': data_clean.NIA, 
      'title': 'NIA',
      'method_name': 'Autoregression'}

plot(data_clean, dic)

# %% [markdown]
# ### ONI

# %%
dic = {'data': data_clean.ONI, 
      'title': 'ONI',
      'method_name': 'Autoregression'}

plot(data_clean, dic)

# %% [markdown]
# ### MWSS

# %%
dic = {'data': data_clean.MWSS, 
      'title': 'MWSS',
      'method_name': 'Autoregression'}

plot(data_clean, dic)
